# %% [markdown]
# ## Types Of Variable Assignment

# %%
age=20
print(age)
# Out:
# 20

# %%
a,b,c=10,20,30
print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %%
e=f=g=5
print(e)
print(f)
print(g)
# Out:
# 5
# 5
# 5

# %% [markdown]
# ### Data Types

# %%
a=5
print(type(a))
# Out:
# <class 'int'>

# %%
a=5.0
print(type(a))
# Out:
# <class 'float'>

# %%
a="hello"
print(type(a))
# Out:
# <class 'str'>

# %%
a=True
print(type(a))
# Out:
# <class 'bool'>

# %%
a=3+7j
print(type(a))
# Out:
# <class 'complex'>

# %%
arr=[1,24,4,5,6]

# %%
print(arr[0])
print(arr[1])
print(arr[2])
print(type(arr))
# Out:
# 1
# 24
# 4
# <class 'list'>

# %%
t=(1,2,3,4,5)
print(t)
print(type(t))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %%
s={1,2,3,4,5}
print(s)
print(type(s))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
a={"name":"python"}
print(a)
print(type(a))
# Out:
# {'name': 'python'}
# <class 'dict'>

# %% [markdown]
# # operators

# %% [markdown]
# ### Arthimatic operator

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
a=10
b=20
c=a-b
print(c)
# Out:
# -10

# %%
a=10
b=20
c=a*b
print(c)
# Out:
# 200

# %%
a=10
b=20
c=a/b#true div
print(c)
# Out:
# 0.5

# %%
a=10
b=20
c=a//b# floor div
print(c)
# Out:
# 0

# %%
a=5
b=2
c=a%b
print(c)
# Out:
# 1

# %%
a=5
b=2
c=b**a
print(c)
# Out:
# 32

# %% [markdown]
# ###
# Relational Operator

# %%
a=10
b=20
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
print(a==b)
print(a!=b)
# Out:
# False
# True
# False
# True
# False
# True
